# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import variation

# %%
# Data acquistion
EducationDataset = pd.read_csv(r'D:\Learning\EstudosDataScience\Projetos\DataScienceProjects\20210826 Olympics Analysis\3 - Dados de Upload\EducationDataset.csv',header=0)
WealthDataset = pd.read_csv(r'D:\Learning\EstudosDataScience\Projetos\DataScienceProjects\20210826 Olympics Analysis\3 - Dados de Upload\WealthDataset.csv',header=0)
OlympicsDataset = pd.read_csv(r'D:\Learning\EstudosDataScience\Projetos\DataScienceProjects\20210826 Olympics Analysis\3 - Dados de Upload\OlympicsDataset.csv',header=0)

# %%
EducationDataset
# Out:
#                                 Country   1990   1991   1992   1993   1994  \
# 0                           Afghanistan  0.122  0.133  0.145  0.156  0.168
# 1                               Albania  0.583  0.588  0.557  0.542  0.541
# 2                               Algeria  0.385  0.395  0.405  0.414  0.424
# 3                               Andorra    NaN    NaN    NaN    NaN    NaN
# 4                                Angola    NaN    NaN    NaN    NaN    NaN
# ..                                  ...    ...    ...    ...    ...    ...
# 184  Venezuela (Bolivarian Republic of)  0.444  0.457  0.466  0.471  0.475
# 185                            Viet Nam  0.348  0.361  0.374  0.387  0.400
# 186                               Yemen  0.219  0.222  0.224  0.227  0.230
# 187                              Zambia  0.365  0.380  0.396  0.411  0.426
# 188                            Zimbabwe  0.423  0.441  0.437  0.443  0.450
#
# ...

# %%
WealthDataset
# Out:
#                       Country  Median    Mean  Gini    Adults
# 0                  Luxembourg  259899  477306  67.0    498000
# 1                   Australia  238072  483755  65.6  19159000
# 2                     Iceland  231462  337787  50.9    255000
# 3                     Belgium  230548  351327  60.3   8993000
# 4                   Hong Kong  173768  503335  74.6   6292000
# ..                        ...     ...     ...   ...       ...
# 163                Mozambique     345    1003  79.1  14186000
# 164                   Burundi     281     728  75.1   5381000
# 165                   Lesotho     264    1226  88.6   1243000
# 166  Central African Republic     212     840  85.9   2161000
# 167                     Haiti     193     767  85.2   6621000
#
# [168 rows x 5 columns]

# %%
OlympicsDataset
# Out:
#                          Country_name  Tag  N_games_S  Gold_S  Silver_S  \
# 0                         Afghanistan  AFG         15       0         0
# 1                             Algeria  ALG         14       5         4
# 2                           Argentina  ARG         25      21        26
# 3                             Armenia  ARM          7       2         8
# 4                         Australasia  ANZ          2       3         4
# ..                                ...  ...        ...     ...       ...
# 151                            Zambia  ZAM         14       0         1
# 152                          Zimbabwe  ZIM         14       3         4
# 153      Independent Olympic Athletes  IOA          3       1         0
# 154  Independent Olympic Participants  IOP          1       0         1
# 155                        Mixed team  ZZX          3      11         6
#
#      Bronze_S  Total_S  N_games_W  Gold_W  Silver_W  Bronze_W  Total_W  \
# ...

# %%
OlympicsDataset = OlympicsDataset.rename(columns={'Country_name':'Country'})

# %% [markdown]
# # Analysis

# %% [markdown]
# #### First Question: How does the education index varies along the years for the 10 best, 10 worst

# %%
# Get the 10 best and 10 worst
tenBest = OlympicsDataset.sort_values('Total_C',ascending=False).head(10)
tenWorst = OlympicsDataset.sort_values('Total_C',ascending=True).head(10)
#tenMostUnstable must have another dataset with medals along the years for each country

# %%
tenBestList = tenBest.Country.tolist()
tenBestList[2] = 'United Kingdom' # Great Britain = United Kingdom
tenBestList[1] = 'Russian Federation' # Changed Soviet union for Russion Federation, i know that is not correct, it is hardly an approximation
tenBestDataset = EducationDataset.loc[EducationDataset.Country.isin(tenBestList)]

# %%
tenWorstList = tenWorst.Country.tolist()
tenWorstDataset = EducationDataset.loc[EducationDataset.Country.isin(tenWorstList)]

# %%
tenWorstDataset
# Out:
#           Country   1990   1991   1992   1993   1994   1995   1996   1997  \
# 26   Burkina Faso    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 47       Djibouti    NaN    NaN    NaN    NaN    NaN  0.171  0.173  0.178
# 54        Eritrea    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 61          Gabon  0.473  0.480  0.487  0.494  0.501  0.509  0.516  0.523
# 134      Paraguay  0.431  0.442  0.451  0.463  0.471  0.480  0.488  0.499
# 146         Samoa  0.577  0.582  0.588  0.593  0.598  0.604  0.609  0.610
# 149       Senegal  0.198  0.198  0.199  0.200  0.201  0.202  0.203  0.204
# 161         Sudan  0.159  0.167  0.175  0.183  0.191  0.198  0.206  0.214
# 170          Togo  0.310  0.322  0.310  0.316  0.321  0.348  0.363  0.371
# 171         Tonga  0.656  0.662  0.668  0.673  0.679  0.685  0.685  0.685
#
#       1998  ...   2010   2011   2012   2013   2014   2015   2016   2017  \
# 26     NaN  ...  0.232  0.245  0.253  0.261  0.264  0.277  0.286  0.298
# ...

# %%
var = variation(tenWorstDataset.loc[:,tenWorstDataset.columns != 'Country'].dropna(how='any',axis=1), axis=1)

# %%
print(var)
# Out:
# [0.17401653 0.08320375 0.02188994 0.03578638 0.04192851 0.02428094
#  0.10388035 0.07072988 0.06552098 0.04474985]

# %%
pd.Series(var)
# Out:
# 0    0.174017
# 1    0.083204
# 2    0.021890
# 3    0.035786
# 4    0.041929
# 5    0.024281
# 6    0.103880
# 7    0.070730
# 8    0.065521
# 9    0.044750
# dtype: float64

# %%
tenWorstDataset.columns
# Out:
# Index(['Country', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')
